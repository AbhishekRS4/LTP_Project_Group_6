# %%
from datasets import load_dataset

# %%
data = load_dataset("webis/Touche23-ValueEval")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 data = load_dataset("webis/Touche23-ValueEval")
#
# File ~/.virtualenvs/nlp/lib/python3.8/site-packages/datasets/load.py:1735, in load_dataset(path, name, data_dir, data_files, split, cache_dir, features, download_config, download_mode, ignore_verifications, keep_in_memory, save_infos, revision, use_auth_token, task, streaming, num_proc, **config_kwargs)
#    1732 ignore_verifications = ignore_verifications or save_infos
#    1734 # Create a dataset builder
# -> 1735 builder_instance = load_dataset_builder(
#    1736     path=path,
#    1737     name=name,
#    1738     data_dir=data_dir,
#    1739     data_files=data_files,
#    1740     cache_dir=cache_dir,
#    1741     features=features,
#    1742     download_config=download_config,
#    1743     download_mode=download_mode,
# ...

# %%
data.save_to_disk('~/datasets/touche23/dummy/')
# Out:
# Saving the dataset (0/1 shards):   0%|          | 0/5393 [00:00<?, ? examples/s]
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 data.save_to_disk('~/datasets/touche23/dummy/')
#
# File ~/.virtualenvs/nlp/lib/python3.8/site-packages/datasets/dataset_dict.py:1186, in DatasetDict.save_to_disk(self, dataset_dict_path, fs, max_shard_size, num_shards, num_proc, storage_options)
#    1184     json.dump({"splits": list(self)}, f)
#    1185 for k, dataset in self.items():
# -> 1186     dataset.save_to_disk(
#    1187         path_join(dataset_dict_path, k),
#    1188         num_shards=num_shards.get(k),
#    1189         max_shard_size=max_shard_size,
#    1190         num_proc=num_proc,
#    1191         storage_options=storage_options,
#    1192     )
#
# ...

# %%
data = load_dataset('wikitext', 'wikitext-103-v1')
# Out:
# ...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 data = load_dataset('wikitext', 'wikitext-103-v1')
#
# File ~/.virtualenvs/nlp/lib/python3.8/site-packages/datasets/load.py:1758, in load_dataset(path, name, data_dir, data_files, split, cache_dir, features, download_config, download_mode, ignore_verifications, keep_in_memory, save_infos, revision, use_auth_token, task, streaming, num_proc, **config_kwargs)
#    1755 try_from_hf_gcs = path not in _PACKAGED_DATASETS_MODULES
#    1757 # Download and prepare data
# -> 1758 builder_instance.download_and_prepare(
#    1759     download_config=download_config,
#    1760     download_mode=download_mode,
#    1761     ignore_verifications=ignore_verifications,
#    1762     try_from_hf_gcs=try_from_hf_gcs,
#    1763     num_proc=num_proc,
#    1764 )
#    1766 # Build dataset for splits
# ...
